# %%
import requests
from pprint import pprint
url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson"
response = requests.get(url).json()
response
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1632930265000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson',
#   'title': 'USGS All Earthquakes, Past Week',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 2366},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '32 km SSW of Mina, Nevada',
#     'time': 1632929343423,
#     'updated': 1632929565331,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823967',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823967.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'nn',
#     'code': '00823967',
#     'ids': ',nn00823967,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.172,
#     'rms': 0.1704,
#     'gap': 187.38,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 32 km SSW of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.2678, 38.1306, 0.1]},
#    'id': 'nn00823967'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': '32 km SSE of Mina, Nevada',
#     'time': 1632928929030,
#     'updated': 1632929264991,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823965',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823965.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'nn',
#     'code': '00823965',
#     'ids': ',nn00823965,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.032,
#     'rms': 0.2795,
#     'gap': 101.45,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 32 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.9091, 38.1439, 15.3]},
#    'id': 'nn00823965'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '60 km SSE of Cantwell, Alaska',
#     'time': 1632928561475,
#     'updated': 1632928761195,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021ci37byl',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021ci37byl.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '021ci37byl',
#     'ids': ',ak021ci37byl,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.75,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 60 km SSE of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.3473, 62.9248, 13.3]},
#    'id': 'ak021ci37byl'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.18,
#     'place': '3 km SE of Carney, Oklahoma',
#     'time': 1632928263950,
#     'updated': 1632929336708,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2021tchk',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ok2021tchk.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 73,
#     'net': 'ok',
#     'code': '2021tchk',
#     'ids': ',ok2021tchk,',
#     'sources': ',ok,',
#     'types': ',origin,phase-data,',
#     'nst': 101,
#     'dmin': 0,
#     'rms': 0.17,
#     'gap': 47,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 3 km SE of Carney, Oklahoma'},
#    'geometry': {'type': 'Point', 'coordinates': [-96.983, 35.79083333, 7.8]},
#    'id': 'ok2021tchk'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.08,
#     'place': '8 km ENE of Pāhala, Hawaii',
#     'time': 1632928237720,
#     'updated': 1632928566200,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72733337',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72733337.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 67,
#     'net': 'hv',
#     'code': '72733337',
#     'ids': ',hv72733337,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 43,
#     'dmin': None,
#     'rms': 0.159999996,
#     'gap': 128,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 8 km ENE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.410995483398, 19.2455005645752, 32.5699996948242]},
#    'id': 'hv72733337'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '17 km ENE of Mono City, California',
#     'time': 1632926749597,
#     'updated': 1632926955598,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823960',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823960.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'nn',
#     'code': '00823960',
#     'ids': ',nn00823960,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.385,
#     'rms': 0.3103,
#     'gap': 120.36,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 17 km ENE of Mono City, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.9579, 38.1051, 5]},
#    'id': 'nn00823960'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.97,
#     'place': '2km NE of The Geysers, CA',
#     'time': 1632926433010,
#     'updated': 1632926529543,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73630971',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73630971.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 14,
#     'net': 'nc',
#     'code': '73630971',
#     'ids': ',nc73630971,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.01659,
#     'rms': 0.02,
#     'gap': 85,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 2km NE of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7456665, 38.788166, 1.46]},
#    'id': 'nc73630971'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '7 km S of Volcano, Hawaii',
#     'time': 1632926206830,
#     'updated': 1632926537220,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72733262',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72733262.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'hv',
#     'code': '72733262',
#     'ids': ',hv72733262,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 9,
#     'dmin': None,
#     'rms': 0.140000001,
#     'gap': 278,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 7 km S of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.223327636719, 19.3754997253418, 1.69000005722046]},
#    'id': 'hv72733262'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '31 km SE of Mina, Nevada',
#     'time': 1632925889397,
#     'updated': 1632926087205,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823956',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823956.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'nn',
#     'code': '00823956',
#     'ids': ',nn00823956,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 0.019,
#     'rms': 0.2083,
#     'gap': 76.05,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 31 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8704, 38.1807, 10.9]},
#    'id': 'nn00823956'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.95,
#     'place': '10km NW of The Geysers, CA',
#     'time': 1632925863170,
#     'updated': 1632925960213,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73630961',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73630961.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 14,
#     'net': 'nc',
#     'code': '73630961',
#     'ids': ',nc73630961,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 21,
#     'dmin': 0.002993,
#     'rms': 0.02,
#     'gap': 103,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 10km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.836998, 38.8358345, 1.81]},
#    'id': 'nc73630961'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '7 km W of Walker, California',
#     'time': 1632925711706,
#     'updated': 1632925895308,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823953',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823953.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'nn',
#     'code': '00823953',
#     'ids': ',nn00823953,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.014,
#     'rms': 0.1616,
#     'gap': 200.56,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 7 km W of Walker, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.5593, 38.5114, 8.5]},
#    'id': 'nn00823953'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.82,
#     'place': '9 km WSW of Volcano, Hawaii',
#     'time': 1632925336630,
#     'updated': 1632925667110,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72733232',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72733232.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 51,
#     'net': 'hv',
#     'code': '72733232',
#     'ids': ',hv72733232,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 35,
#     'dmin': None,
#     'rms': 0.159999996,
#     'gap': 63,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 9 km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.322326660156, 19.4106674194336, 3.45000004768372]},
#    'id': 'hv72733232'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '6km NW of The Geysers, CA',
#     'time': 1632923105670,
#     'updated': 1632923199280,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73630946',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73630946.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'nc',
#     'code': '73630946',
#     'ids': ',nc73630946,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.007692,
#     'rms': 0.01,
#     'gap': 64,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 6km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7956696, 38.8156662, 2.51]},
#    'id': 'nc73630946'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': '26 km SSE of Mina, Nevada',
#     'time': 1632923002801,
#     'updated': 1632923243717,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823952',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823952.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'nn',
#     'code': '00823952',
#     'ids': ',nn00823952,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.026,
#     'rms': 0.1196,
#     'gap': 100.73,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 26 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.994, 38.1743, 1.2]},
#    'id': 'nn00823952'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.83000004,
#     'place': '4 km NE of Pāhala, Hawaii',
#     'time': 1632922628420,
#     'updated': 1632922813620,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72733157',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72733157.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 52,
#     'net': 'hv',
#     'code': '72733157',
#     'ids': ',hv72733157,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 42,
#     'dmin': None,
#     'rms': 0.119999997,
#     'gap': 106,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 4 km NE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.453994750977, 19.2333335876465, 29.8099994659424]},
#    'id': 'hv72733157'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.6,
#     'place': '6 km SW of Coleville, California',
#     'time': 1632922516152,
#     'updated': 1632922754164,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823950',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823950.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 6,
#     'net': 'nn',
#     'code': '00823950',
#     'ids': ',nn00823950,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.004,
#     'rms': 0.2304,
#     'gap': 222.63,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 6 km SW of Coleville, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.5614, 38.5299, 8.6]},
#    'id': 'nn00823950'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.83,
#     'place': '3 km S of Pāhala, Hawaii',
#     'time': 1632922227750,
#     'updated': 1632922558120,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72733152',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72733152.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 52,
#     'net': 'hv',
#     'code': '72733152',
#     'ids': ',hv72733152,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 47,
#     'dmin': None,
#     'rms': 0.109999999,
#     'gap': 82,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 3 km S of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.480834960938, 19.173999786377, 35.2999992370605]},
#    'id': 'hv72733152'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.52,
#     'place': '96 km NNW of Charlotte Amalie, U.S. Virgin Islands',
#     'time': 1632921441690,
#     'updated': 1632924924262,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2021272003',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2021272003.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 191,
#     'net': 'pr',
#     'code': '2021272003',
#     'ids': ',pr2021272003,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.9071,
#     'rms': 0.23,
#     'gap': 300,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 96 km NNW of Charlotte Amalie, U.S. Virgin Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-65.1168, 19.1993, 38]},
#    'id': 'pr2021272003'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '43 km NNE of Petersville, Alaska',
#     'time': 1632921421730,
#     'updated': 1632921629364,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021ci20ohp',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021ci20ohp.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ak',
#     'code': '021ci20ohp',
#     'ids': ',ak021ci20ohp,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.59,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 43 km NNE of Petersville, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.5409, 62.8709, 86.9]},
#    'id': 'ak021ci20ohp'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': '3 km SW of Coleville, California',
#     'time': 1632921365808,
#     'updated': 1632921536202,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823948',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823948.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'nn',
#     'code': '00823948',
#     'ids': ',nn00823948,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 9,
#     'dmin': 0.03,
#     'rms': 0.0847,
#     'gap': 131.92,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 3 km SW of Coleville, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.5344, 38.5476, 7.2]},
#    'id': 'nn00823948'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.92999995,
#     'place': '5 km NE of Pāhala, Hawaii',
#     'time': 1632921254200,
#     'updated': 1632921444530,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72733117',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72733117.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 57,
#     'net': 'hv',
#     'code': '72733117',
#     'ids': ',hv72733117,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 46,
#     'dmin': None,
#     'rms': 0.129999995,
#     'gap': 121,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 5 km NE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.432662963867, 19.2334995269775, 32.5499992370605]},
#    'id': 'hv72733117'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.66,
#     'place': '2km ENE of The Geysers, CA',
#     'time': 1632920543750,
#     'updated': 1632920640657,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73630921',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73630921.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 7,
#     'net': 'nc',
#     'code': '73630921',
#     'ids': ',nc73630921,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 11,
#     'dmin': 0.003806,
#     'rms': 0.05,
#     'gap': 114,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 2km ENE of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7320023, 38.7841682, 1.05]},
#    'id': 'nc73630921'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.7,
#     'place': '19 km ENE of Mono City, California',
#     'time': 1632920138561,
#     'updated': 1632920395390,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823947',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823947.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'nn',
#     'code': '00823947',
#     'ids': ',nn00823947,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 9,
#     'dmin': 0.375,
#     'rms': 0.1995,
#     'gap': 217.07,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 19 km ENE of Mono City, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.9595, 38.1387, 0]},
#    'id': 'nn00823947'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': '0 km ENE of Walker, California',
#     'time': 1632919390539,
#     'updated': 1632919683526,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823946',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823946.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'nn',
#     'code': '00823946',
#     'ids': ',nn00823946,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 8,
#     'dmin': 0.026,
#     'rms': 0.0518,
#     'gap': 97.15,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 0 km ENE of Walker, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.4671, 38.5181, 4.4]},
#    'id': 'nn00823946'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '21 km E of Susitna North, Alaska',
#     'time': 1632919151963,
#     'updated': 1632919515759,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021ci1jzfg',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021ci1jzfg.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ak',
#     'code': '021ci1jzfg',
#     'ids': ',ak021ci1jzfg,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.38,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 21 km E of Susitna North, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.4374, 62.1933, 23.7]},
#    'id': 'ak021ci1jzfg'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '26 km WNW of Clam Gulch, Alaska',
#     'time': 1632918964028,
#     'updated': 1632919114919,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021ci1jbo2',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021ci1jbo2.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ak',
#     'code': '021ci1jbo2',
#     'ids': ',ak021ci1jbo2,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.63,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 26 km WNW of Clam Gulch, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.7966, 60.3635, 56.6]},
#    'id': 'ak021ci1jbo2'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '45 km SSW of Goldfield, Nevada',
#     'time': 1632918831437,
#     'updated': 1632919042315,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823943',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823943.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'nn',
#     'code': '00823943',
#     'ids': ',nn00823943,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 8,
#     'dmin': 0.162,
#     'rms': 0.471,
#     'gap': 306.77,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 45 km SSW of Goldfield, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.4581, 37.3398, 1.3]},
#    'id': 'nn00823943'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.27,
#     'place': '28km SE of Markleeville, CA',
#     'time': 1632918795170,
#     'updated': 1632930080296,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73630901',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73630901.geojson',
#     'felt': 10,
#     'cdi': 2.9,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 167,
#     'net': 'nc',
#     'code': '73630901',
#     'ids': ',nc73630901,nn00823940,',
#     'sources': ',nc,nn,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 14,
#     'dmin': None,
#     'rms': 0.07,
#     'gap': 81,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 28km SE of Markleeville, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-119.5388336, 38.5395012, 6.48]},
#    'id': 'nc73630901'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.4,
#     'place': '32 km SE of Mina, Nevada',
#     'time': 1632918537240,
#     'updated': 1632918772731,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823939',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823939.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 2,
#     'net': 'nn',
#     'code': '00823939',
#     'ids': ',nn00823939,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.016,
#     'rms': 0.1084,
#     'gap': 105.59,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.4 - 32 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8924, 38.157, 7.8]},
#    'id': 'nn00823939'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.59,
#     'place': '59 km ESE of West Yellowstone, Montana',
#     'time': 1632918482210,
#     'updated': 1632922281240,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60460387',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60460387.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'uu',
#     'code': '60460387',
#     'ids': ',uu60460387,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 0.1063,
#     'rms': 0.14,
#     'gap': 85,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 59 km ESE of West Yellowstone, Montana'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-110.4121667, 44.4466667, 7.71]},
#    'id': 'uu60460387'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '72 km NE of Lake Minchumina, Alaska',
#     'time': 1632918460958,
#     'updated': 1632918714074,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021ci1hh2e',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021ci1hh2e.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '021ci1hh2e',
#     'ids': ',ak021ci1hh2e,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.76,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 72 km NE of Lake Minchumina, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.1397, 64.2829, 4.4]},
#    'id': 'ak021ci1hh2e'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '35 km SSW of Nanwalek, Alaska',
#     'time': 1632918433823,
#     'updated': 1632918713943,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021ci1heza',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021ci1heza.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '021ci1heza',
#     'ids': ',ak021ci1heza,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.6,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 35 km SSW of Nanwalek, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.2273, 59.0754, 28.9]},
#    'id': 'ak021ci1heza'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '18 km ENE of Mono City, California',
#     'time': 1632918411826,
#     'updated': 1632930099285,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823935',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823935.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'nn',
#     'code': '00823935',
#     'ids': ',nn00823935,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 0.095,
#     'rms': 0.1332,
#     'gap': 109.84,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 18 km ENE of Mono City, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.9497, 38.1102, 6.4]},
#    'id': 'nn00823935'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.87,
#     'place': '12km ENE of Julian, CA',
#     'time': 1632917505770,
#     'updated': 1632926684759,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40059232',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40059232.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'ci',
#     'code': '40059232',
#     'ids': ',ci40059232,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 28,
#     'dmin': 0.0423,
#     'rms': 0.19,
#     'gap': 97,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 12km ENE of Julian, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.4791667, 33.102, 13.28]},
#    'id': 'ci40059232'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '19 km SSW of Susitna North, Alaska',
#     'time': 1632917366531,
#     'updated': 1632917762016,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021ci1dl2n',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021ci1dl2n.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ak',
#     'code': '021ci1dl2n',
#     'ids': ',ak021ci1dl2n,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.57,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 19 km SSW of Susitna North, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.025, 62.0037, 35.7]},
#    'id': 'ak021ci1dl2n'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.23,
#     'place': '16km ENE of Yucaipa, CA',
#     'time': 1632917064020,
#     'updated': 1632917718380,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40059224',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40059224.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 77,
#     'net': 'ci',
#     'code': '40059224',
#     'ids': ',ci40059224,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 77,
#     'dmin': 0.03592,
#     'rms': 0.18,
#     'gap': 29,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 16km ENE of Yucaipa, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.894, 34.1026667, 12.24]},
#    'id': 'ci40059224'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '70 km ENE of Chase, Alaska',
#     'time': 1632917024701,
#     'updated': 1632917280773,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021ci1cc5e',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021ci1cc5e.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ak',
#     'code': '021ci1cc5e',
#     'ids': ',ak021ci1cc5e,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.9,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 70 km ENE of Chase, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.8064, 62.6491, 47]},
#    'id': 'ak021ci1cc5e'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.88999999,
#     'place': '2 km SSE of Pāhala, Hawaii',
#     'time': 1632916855120,
#     'updated': 1632917054000,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72733007',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72733007.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 55,
#     'net': 'hv',
#     'code': '72733007',
#     'ids': ',hv72733007,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 41,
#     'dmin': None,
#     'rms': 0.140000001,
#     'gap': 158,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 2 km SSE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.470001220703, 19.1788330078125, 34.9000015258789]},
#    'id': 'hv72733007'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.16000009,
#     'place': '2 km SSE of Pāhala, Hawaii',
#     'time': 1632916744630,
#     'updated': 1632916926000,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72733002',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72733002.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 72,
#     'net': 'hv',
#     'code': '72733002',
#     'ids': ',hv72733002,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 41,
#     'dmin': None,
#     'rms': 0.119999997,
#     'gap': 153,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 2 km SSE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.47200012207, 19.1805000305176, 35.2700004577637]},
#    'id': 'hv72733002'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.83,
#     'place': '15 km SE of Lincoln, Montana',
#     'time': 1632916627350,
#     'updated': 1632923444250,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/mb80524944',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/mb80524944.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 11,
#     'net': 'mb',
#     'code': '80524944',
#     'ids': ',mb80524944,',
#     'sources': ',mb,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.04,
#     'rms': 0.14,
#     'gap': 97,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 15 km SE of Lincoln, Montana'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-112.5113333, 46.8745, 12.93]},
#    'id': 'mb80524944'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '17km E of Little Lake, CA',
#     'time': 1632916558820,
#     'updated': 1632916767530,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40059216',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40059216.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ci',
#     'code': '40059216',
#     'ids': ',ci40059216,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 18,
#     'dmin': 0.06998,
#     'rms': 0.15,
#     'gap': 56,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 17km E of Little Lake, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.7251667, 35.913, 8.46]},
#    'id': 'ci40059216'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '2 km S of Pýrgos, Greece',
#     'time': 1632916488147,
#     'updated': 1632928631512,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000fq3y',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000fq3y.geojson',
#     'felt': 1,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '6000fq3y',
#     'ids': ',us6000fq3y,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.371,
#     'rms': 0.82,
#     'gap': 69,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 2 km S of Pýrgos, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [25.1557, 34.9866, 10]},
#    'id': 'us6000fq3y'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': '59 km ESE of West Yellowstone, Montana',
#     'time': 1632916456700,
#     'updated': 1632929213870,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60460377',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60460377.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'uu',
#     'code': '60460377',
#     'ids': ',uu60460377,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.1049,
#     'rms': 0.1,
#     'gap': 86,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 59 km ESE of West Yellowstone, Montana'},
#    'geometry': {'type': 'Point', 'coordinates': [-110.4195, 44.4451667, 2.53]},
#    'id': 'uu60460377'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.64,
#     'place': '59 km ESE of West Yellowstone, Montana',
#     'time': 1632916372590,
#     'updated': 1632922029610,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60460372',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60460372.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 41,
#     'net': 'uu',
#     'code': '60460372',
#     'ids': ',uu60460372,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.1062,
#     'rms': 0.12,
#     'gap': 86,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 59 km ESE of West Yellowstone, Montana'},
#    'geometry': {'type': 'Point', 'coordinates': [-110.4145, 44.4435, 7.34]},
#    'id': 'uu60460372'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.72,
#     'place': '10 km SSE of Volcano, Hawaii',
#     'time': 1632916137950,
#     'updated': 1632916469420,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72732977',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72732977.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 46,
#     'net': 'hv',
#     'code': '72732977',
#     'ids': ',hv72732977,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 36,
#     'dmin': None,
#     'rms': 0.25999999,
#     'gap': 73,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 10 km SSE of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.18049621582, 19.3646659851074, 2.25]},
#    'id': 'hv72732977'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': '18 km ENE of Mono City, California',
#     'time': 1632915897115,
#     'updated': 1632916083727,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823932',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823932.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'nn',
#     'code': '00823932',
#     'ids': ',nn00823932,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.382,
#     'rms': 0.246,
#     'gap': 110.85,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 18 km ENE of Mono City, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.9545, 38.1063, 1.1]},
#    'id': 'nn00823932'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': '29 km SE of Mina, Nevada',
#     'time': 1632915704643,
#     'updated': 1632915912437,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823930',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823930.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'nn',
#     'code': '00823930',
#     'ids': ',nn00823930,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.033,
#     'rms': 0.293,
#     'gap': 110.8,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 29 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8888, 38.1877, 5.1]},
#    'id': 'nn00823930'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.18,
#     'place': '6 km ENE of Pāhala, Hawaii',
#     'time': 1632915544260,
#     'updated': 1632915874040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72732962',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72732962.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 73,
#     'net': 'hv',
#     'code': '72732962',
#     'ids': ',hv72732962,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 44,
#     'dmin': None,
#     'rms': 0.159999996,
#     'gap': 133,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 6 km ENE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.421829223633, 19.2234992980957, 32.9799995422363]},
#    'id': 'hv72732962'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '156 km ESE of Neiafu, Tonga',
#     'time': 1632914592588,
#     'updated': 1632927009040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000fq3q',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000fq3q.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '6000fq3q',
#     'ids': ',us6000fq3q,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 5.279,
#     'rms': 0.43,
#     'gap': 130,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 156 km ESE of Neiafu, Tonga'},
#    'geometry': {'type': 'Point', 'coordinates': [-172.5962, -19.1598, 10]},
#    'id': 'us6000fq3q'},
#   {'type': 'Feature',
#    'properties': {'mag': 2,
#     'place': '5 km S of Pāhala, Hawaii',
#     'time': 1632914550610,
#     'updated': 1632914748860,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72732932',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72732932.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'hv',
#     'code': '72732932',
#     'ids': ',hv72732932,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 40,
#     'dmin': None,
#     'rms': 0.159999996,
#     'gap': 129,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 5 km S of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.476165771484, 19.1568336486816, 33.5099983215332]},
#    'id': 'hv72732932'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.79,
#     'place': '19km N of Pine Mountain Club, CA',
#     'time': 1632914365380,
#     'updated': 1632914590272,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40059208',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40059208.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 49,
#     'net': 'ci',
#     'code': '40059208',
#     'ids': ',ci40059208,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 28,
#     'dmin': 0.2049,
#     'rms': 0.31,
#     'gap': 35,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 19km N of Pine Mountain Club, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.136, 35.0178333, 12.09]},
#    'id': 'ci40059208'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '7 km NNE of Diamond Ridge, Alaska',
#     'time': 1632914255501,
#     'updated': 1632914525977,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021ci0tvwf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021ci0tvwf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ak',
#     'code': '021ci0tvwf',
#     'ids': ',ak021ci0tvwf,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.64,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 7 km NNE of Diamond Ridge, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.5305, 59.7408, 47.2]},
#    'id': 'ak021ci0tvwf'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.89,
#     'place': '4km SW of Banning, CA',
#     'time': 1632914160830,
#     'updated': 1632914378247,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40059200',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40059200.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'ci',
#     'code': '40059200',
#     'ids': ',ci40059200,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 24,
#     'dmin': 0.06429,
#     'rms': 0.24,
#     'gap': 126,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 4km SW of Banning, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.9081667, 33.8988333, 11.84]},
#    'id': 'ci40059200'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.64,
#     'place': '8 km SSE of Volcano, Hawaii',
#     'time': 1632913506540,
#     'updated': 1632914322130,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72732917',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72732917.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 6,
#     'net': 'hv',
#     'code': '72732917',
#     'ids': ',hv72732917,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': None,
#     'rms': 0.1,
#     'gap': 115,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 8 km SSE of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.216333333333, 19.3708333333333, 1.77]},
#    'id': 'hv72732917'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.17,
# ...
#     'nst': 14,
#     'dmin': 0.0111,
#     'rms': 0.02,
#     'gap': 73,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 8km W of Cobb, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8093338, 38.8344994, 2.06]},
#    'id': 'nc73629761'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '28 km SSE of Mina, Nevada',
#     'time': 1632663709307,
#     'updated': 1632868988179,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823619',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823619.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'nn',
#     'code': '00823619',
#     'ids': ',nn00823619,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.022,
#     'rms': 0.0981,
#     'gap': 104.59,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 28 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.9663, 38.1598, 5.1]},
#    'id': 'nn00823619'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.39,
#     'place': '23km ESE of Little Lake, CA',
#     'time': 1632663092850,
#     'updated': 1632756520152,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39819551',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39819551.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 2,
#     'net': 'ci',
#     'code': '39819551',
#     'ids': ',ci39819551,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.07074,
#     'rms': 0.11,
#     'gap': 95,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.4 - 23km ESE of Little Lake, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.664, 35.8615, 11.23]},
#    'id': 'ci39819551'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.35,
#     'place': '1 km SSW of Quinton, Oklahoma',
#     'time': 1632662993560,
#     'updated': 1632770324885,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2021swro',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ok2021swro.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 28,
#     'net': 'ok',
#     'code': '2021swro',
#     'ids': ',ok2021swro,',
#     'sources': ',ok,',
#     'types': ',origin,phase-data,',
#     'nst': 44,
#     'dmin': 0.1214761622,
#     'rms': 0.29,
#     'gap': 72,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 1 km SSW of Quinton, Oklahoma'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.3775, 35.10583333, 7.69]},
#    'id': 'ok2021swro'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.67,
#     'place': '10km NE of San Martin, CA',
#     'time': 1632662979360,
#     'updated': 1632768224993,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73629756',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73629756.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 7,
#     'net': 'nc',
#     'code': '73629756',
#     'ids': ',nc73629756,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.07371,
#     'rms': 0.08,
#     'gap': 91,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 10km NE of San Martin, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-121.5235, 37.1398333, 8.18]},
#    'id': 'nc73629756'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '29 km NW of Beluga, Alaska',
#     'time': 1632662328176,
#     'updated': 1632662595831,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021cd3eyba',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021cd3eyba.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'ak',
#     'code': '021cd3eyba',
#     'ids': ',ak021cd3eyba,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.51,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 29 km NW of Beluga, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.468, 61.3238, 73.5]},
#    'id': 'ak021cd3eyba'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '6 km ENE of Walker, California',
#     'time': 1632661947091,
#     'updated': 1632868799312,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823617',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823617.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'nn',
#     'code': '00823617',
#     'ids': ',nn00823617,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 9,
#     'dmin': 0.037,
#     'rms': 0.117,
#     'gap': 77.7,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 6 km ENE of Walker, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.4049, 38.53, 1.3]},
#    'id': 'nn00823617'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '6 km ENE of Walker, California',
#     'time': 1632661829792,
#     'updated': 1632662012916,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823613',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823613.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'nn',
#     'code': '00823613',
#     'ids': ',nn00823613,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.043,
#     'rms': 0.2104,
#     'gap': 104.44,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 6 km ENE of Walker, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.4056, 38.539, 0]},
#    'id': 'nn00823613'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': 'Banda Sea',
#     'time': 1632661639480,
#     'updated': 1632662736040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fels',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000fels.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000fels',
#     'ids': ',us7000fels,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.418,
#     'rms': 0.47,
#     'gap': 98,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - Banda Sea'},
#    'geometry': {'type': 'Point', 'coordinates': [129.9092, -5.9829, 139.89]},
#    'id': 'us7000fels'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.3,
#     'place': '34 km NW of Stanley, Idaho',
#     'time': 1632661531135,
#     'updated': 1632665058040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000felr',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000felr.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 81,
#     'net': 'us',
#     'code': '7000felr',
#     'ids': ',mb80524599,us7000felr,',
#     'sources': ',mb,us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.064,
#     'rms': 0.62,
#     'gap': 56,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 34 km NW of Stanley, Idaho'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.195, 44.4658, 10]},
#    'id': 'us7000felr'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.4,
#     'place': '31 km SSE of Mina, Nevada',
#     'time': 1632661528779,
#     'updated': 1632661781628,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823612',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823612.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 2,
#     'net': 'nn',
#     'code': '00823612',
#     'ids': ',nn00823612,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 11,
#     'dmin': 0.028,
#     'rms': 0.2171,
#     'gap': 105.18,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.4 - 31 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.9073, 38.1531, 12.2]},
#    'id': 'nn00823612'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '17 km NNE of Four Mile Road, Alaska',
#     'time': 1632661471691,
#     'updated': 1632661704004,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021cd3bx0h',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021cd3bx0h.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': '021cd3bx0h',
#     'ids': ',ak021cd3bx0h,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.8,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 17 km NNE of Four Mile Road, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.0427, 64.7564, 21.7]},
#    'id': 'ak021cd3bx0h'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '3 km SSW of Coleville, California',
#     'time': 1632661078511,
#     'updated': 1632661263576,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823608',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823608.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'nn',
#     'code': '00823608',
#     'ids': ',nn00823608,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.029,
#     'rms': 0.1352,
#     'gap': 88.85,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 3 km SSW of Coleville, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.527, 38.5379, 5.9]},
#    'id': 'nn00823608'},
#   {'type': 'Feature',
#    'properties': {'mag': 1,
#     'place': '33 km ENE of Lee Vining, California',
#     'time': 1632660935784,
#     'updated': 1632661134538,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823605',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823605.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 15,
#     'net': 'nn',
#     'code': '00823605',
#     'ids': ',nn00823605,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 0.284,
#     'rms': 0.3476,
#     'gap': 119.01,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 33 km ENE of Lee Vining, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.7605, 38.0509, 0]},
#    'id': 'nn00823605'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.6,
#     'place': '8 km E of Walker, California',
#     'time': 1632660337728,
#     'updated': 1632776279237,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823784',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823784.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 6,
#     'net': 'nn',
#     'code': '00823784',
#     'ids': ',nn00823784,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 5,
#     'dmin': 0.048,
#     'rms': 0.1064,
#     'gap': 308.64,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 8 km E of Walker, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.3783, 38.516, 2.1]},
#    'id': 'nn00823784'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.5,
#     'place': '31 km SSE of Mina, Nevada',
#     'time': 1632660330947,
#     'updated': 1632776276182,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823604',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823604.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 4,
#     'net': 'nn',
#     'code': '00823604',
#     'ids': ',nn00823604,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 5,
#     'dmin': 0.032,
#     'rms': 0.0522,
#     'gap': 144.92,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.5 - 31 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.9113, 38.1511, 6.7]},
#    'id': 'nn00823604'},
#   {'type': 'Feature',
#    'properties': {'mag': -0.2,
#     'place': '2 km WSW of Walker, California',
#     'time': 1632659718642,
#     'updated': 1632768644212,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00823603',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00823603.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'nn',
#     'code': '00823603',
#     'ids': ',nn00823603,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 7,
#     'dmin': 0.003,
#     'rms': 0.0401,
#     'gap': 97.26,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M -0.2 - 2 km WSW of Walker, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.4985, 38.5088, 5.6]},
#    'id': 'nn00823603'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.1,
#     'place': '72 km N of Petersville, Alaska',
#     'time': 1632659406712,
#     'updated': 1632661703881,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021cd2vw4i',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021cd2vw4i.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 68,
#     'net': 'ak',
#     'code': '021cd2vw4i',
#     'ids': ',ak021cd2vw4i,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.61,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 72 km N of Petersville, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.5556, 63.1427, 113]},
#    'id': 'ak021cd2vw4i'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '94 km SE of Nikolai, Alaska',
#     'time': 1632659395702,
#     'updated': 1632659600090,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021cd2vw5v',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak021cd2vw5v.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ak',
#     'code': '021cd2vw5v',
#     'ids': ',ak021cd2vw5v,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.85,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 94 km SE of Nikolai, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-153.0414, 62.4329, 0]},
#    'id': 'ak021cd2vw5v'},
#   ...],
#  'bbox': [-179.4605, -59.911, -3.41, 179.5925, 82.9545, 638.39]}

# %%
import matplotlib.pyplot as plt
import pandas as pd
depths = []
for earthquake in response["features"]:
    depths.append(float(earthquake["geometry"]["coordinates"][2]))

plt.plot(depths)
# Out:
# <AxesSubplot:>
